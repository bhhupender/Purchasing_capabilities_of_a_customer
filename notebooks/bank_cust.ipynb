# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
bank_cust = pd.read_csv('../data/bank_transactions.csv')
bank_cust.head()
# Out:
#   TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0            T1   C5841053  10-01-1994          F   JAMSHEDPUR
# 1            T2   C2142763  04-04-1957          M      JHAJJAR
# 2            T3   C4417068  26-11-1996          F       MUMBAI
# 3            T4   C5342380  14-09-1973          F       MUMBAI
# 4            T5   C9031234  24-03-1988          F  NAVI MUMBAI
#
#    CustAccountBalance TransactionDate  TransactionTime  \
# 0            17819.05      02-08-2016           143207
# 1             2270.69      02-08-2016           141858
# 2            17874.44      02-08-2016           142712
# 3           866503.21      02-08-2016           142714
# 4             6714.43      02-08-2016           181156
#
#    TransactionAmount (INR)
# 0                     25.0
# 1                  27999.0
# 2                    459.0
# 3                   2060.0
# 4                   1762.5

# %%
bank_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048567 entries, 0 to 1048566
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   TransactionID            1048567 non-null  object
#  1   CustomerID               1048567 non-null  object
#  2   CustomerDOB              1045170 non-null  object
#  3   CustGender               1047467 non-null  object
#  4   CustLocation             1048416 non-null  object
#  5   CustAccountBalance       1046198 non-null  float64
#  6   TransactionDate          1048567 non-null  object
#  7   TransactionTime          1048567 non-null  int64
#  8   TransactionAmount (INR)  1048567 non-null  float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 72.0+ MB

# %%
bank_cust.describe()
# Out:
#        CustAccountBalance  TransactionTime  TransactionAmount (INR)
# count        1.046198e+06     1.048567e+06             1.048567e+06
# mean         1.154035e+05     1.570875e+05             1.574335e+03
# std          8.464854e+05     5.126185e+04             6.574743e+03
# min          0.000000e+00     0.000000e+00             0.000000e+00
# 25%          4.721760e+03     1.240300e+05             1.610000e+02
# 50%          1.679218e+04     1.642260e+05             4.590300e+02
# 75%          5.765736e+04     2.000100e+05             1.200000e+03
# max          1.150355e+08     2.359590e+05             1.560035e+06

# %% [markdown]
# Exploratory Data Analysis

# %%
bank_eda = bank_cust.copy()

# %%
bank_eda.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Any Null Values

# %%
null_values = bank_eda.isnull().sum()

# %%
null_values.values
# Out:
# array([   0,    0, 3397, 1100,  151, 2369,    0,    0,    0], dtype=int64)

# %%
null_values.plot(kind='bar',cmap='viridis')
plt.xlabel('Columns')
plt.ylabel('Count of Null Values')
plt.show()

# %% [markdown]
# Counts of Categorical values?

# %%
sns.countplot(data=bank_eda,x='CustGender')
plt.show()

print(bank_eda['CustLocation'].value_counts())
# Out:
# CustLocation
# MUMBAI                         103595
# NEW DELHI                       84928
# BANGALORE                       81555
# GURGAON                         73818
# DELHI                           71019
#                                 ...
# ROAD (E) THANE                      1
# TO APOLO PHARMACY BANGALORE         1
# PILLAR NO 725 NEW DELHI             1
# COMPANY BANGALORE                   1
# IMPERIA THANE WEST                  1
# Name: count, Length: 9355, dtype: int64

# %% [markdown]
# Boxplot for Numerical Columns

# %%
num_columns = ['CustAccountBalance','TransactionAmount (INR)']
for col in num_columns:
    sns.boxplot(data=bank_eda,y=col)
    plt.show()

# %%
(bank_eda['CustLocation'].value_counts()).sort_values(ascending=False).iloc[:10]
# Out:
# CustLocation
# MUMBAI       103595
# NEW DELHI     84928
# BANGALORE     81555
# GURGAON       73818
# DELHI         71019
# NOIDA         32784
# CHENNAI       30009
# PUNE          25851
# HYDERABAD     23049
# THANE         21505
# Name: count, dtype: int64

# %% [markdown]
# Year of Transaction and Customer Age as per Transaction Year

# %%
from datetime import datetime,date

bank_eda['TransactionDate'] = pd.to_datetime(bank_eda['TransactionDate'],format='mixed')
bank_eda['TransactionDate'] = bank_eda['TransactionDate'].apply(lambda x: x - pd.DateOffset(years=100) if x > datetime.now() else x)

# %%
bank_eda.head()
# Out:
#   TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0            T1   C5841053  10-01-1994          F   JAMSHEDPUR
# 1            T2   C2142763  04-04-1957          M      JHAJJAR
# 2            T3   C4417068  26-11-1996          F       MUMBAI
# 3            T4   C5342380  14-09-1973          F       MUMBAI
# 4            T5   C9031234  24-03-1988          F  NAVI MUMBAI
#
#    CustAccountBalance TransactionDate  TransactionTime  \
# 0            17819.05      2016-02-08           143207
# 1             2270.69      2016-02-08           141858
# 2            17874.44      2016-02-08           142712
# 3           866503.21      2016-02-08           142714
# 4             6714.43      2016-02-08           181156
#
#    TransactionAmount (INR)
# 0                     25.0
# 1                  27999.0
# 2                    459.0
# 3                   2060.0
# 4                   1762.5

# %%
bank_eda['TransactionYear'] = bank_eda['TransactionDate'].dt.year
bank_eda.head()
# Out:
#   TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0            T1   C5841053  10-01-1994          F   JAMSHEDPUR
# 1            T2   C2142763  04-04-1957          M      JHAJJAR
# 2            T3   C4417068  26-11-1996          F       MUMBAI
# 3            T4   C5342380  14-09-1973          F       MUMBAI
# 4            T5   C9031234  24-03-1988          F  NAVI MUMBAI
#
#    CustAccountBalance TransactionDate  TransactionTime  \
# 0            17819.05      2016-02-08           143207
# 1             2270.69      2016-02-08           141858
# 2            17874.44      2016-02-08           142712
# 3           866503.21      2016-02-08           142714
# 4             6714.43      2016-02-08           181156
#
#    TransactionAmount (INR)  TransactionYear
# 0                     25.0             2016
# 1                  27999.0             2016
# 2                    459.0             2016
# 3                   2060.0             2016
# 4                   1762.5             2016

# %%
bank_eda['CustomerDOB'] = pd.to_datetime(bank_eda['CustomerDOB'],format='mixed')
bank_eda['CustomerDOB'] = bank_eda['CustomerDOB'].apply(lambda x: x - pd.DateOffset(years=100) if x > datetime.now() else x)
bank_eda['CustomerYear'] = bank_eda['CustomerDOB'].dt.year
bank_eda.head()
# Out:
#   TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0            T1   C5841053  1994-10-01          F   JAMSHEDPUR
# 1            T2   C2142763  1957-04-04          M      JHAJJAR
# 2            T3   C4417068  1996-11-26          F       MUMBAI
# 3            T4   C5342380  1973-09-14          F       MUMBAI
# 4            T5   C9031234  1988-03-24          F  NAVI MUMBAI
#
#    CustAccountBalance TransactionDate  TransactionTime  \
# 0            17819.05      2016-02-08           143207
# 1             2270.69      2016-02-08           141858
# 2            17874.44      2016-02-08           142712
# 3           866503.21      2016-02-08           142714
# 4             6714.43      2016-02-08           181156
#
#    TransactionAmount (INR)  TransactionYear  CustomerYear
# 0                     25.0             2016        1994.0
# 1                  27999.0             2016        1957.0
# 2                    459.0             2016        1996.0
# 3                   2060.0             2016        1973.0
# 4                   1762.5             2016        1988.0

# %%
bank_eda['CustomerAge'] = bank_eda['TransactionYear'] - bank_eda['CustomerYear']
bank_eda.head()
# Out:
#   TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0            T1   C5841053  1994-10-01          F   JAMSHEDPUR
# 1            T2   C2142763  1957-04-04          M      JHAJJAR
# 2            T3   C4417068  1996-11-26          F       MUMBAI
# 3            T4   C5342380  1973-09-14          F       MUMBAI
# 4            T5   C9031234  1988-03-24          F  NAVI MUMBAI
#
#    CustAccountBalance TransactionDate  TransactionTime  \
# 0            17819.05      2016-02-08           143207
# 1             2270.69      2016-02-08           141858
# 2            17874.44      2016-02-08           142712
# 3           866503.21      2016-02-08           142714
# 4             6714.43      2016-02-08           181156
#
#    TransactionAmount (INR)  TransactionYear  CustomerYear  CustomerAge
# 0                     25.0             2016        1994.0         22.0
# 1                  27999.0             2016        1957.0         59.0
# 2                    459.0             2016        1996.0         20.0
# 3                   2060.0             2016        1973.0         43.0
# 4                   1762.5             2016        1988.0         28.0

# %%
bank_eda[bank_eda.CustomerAge > 200]
# Out:
#         TransactionID CustomerID CustomerDOB CustGender  \
# 16                T17   C1376215  1800-01-01          M
# 22                T23   C7018081  1800-01-01          M
# 28                T29   C7935438  1800-01-01          M
# 35                T36   C1211387  1800-01-01          M
# 151              T152   C3334638  1800-01-01          M
# ...               ...        ...         ...        ...
# 1048443      T1048444   C7261226  1800-01-01          M
# 1048452      T1048453   C3813481  1800-01-01          M
# 1048531      T1048532   C6937679  1800-01-01          M
# 1048533      T1048534   C7431884  1800-01-01          M
# 1048540      T1048541   C1528025  1800-01-01          M
#
#                      CustLocation  CustAccountBalance TransactionDate  \
# 16                         MUMBAI            77495.15      2016-01-08
# 22       WAYS PANCHKUVA AHMEDABAD              143.07      2016-03-08
# 28                         MOHALI           969436.12      2016-03-08
# 35                      AHMEDABAD            11791.25      2016-03-08
# 151                          PUNE              700.00      2016-09-08
# ...                           ...                 ...             ...
# 1048443                    BHILAI             1393.33      2016-09-18
# 1048452                 NEW DELHI           984605.24      2016-09-18
# 1048531                 NEW DELHI            50698.90      2016-09-18
# 1048533            MANDIR DHANBAD            53771.64      2016-09-18
# 1048540                    MUMBAI           230894.59      2016-09-18
#
#          TransactionTime  TransactionAmount (INR)  TransactionYear  \
# 16                124727                  1423.11             2016
# 22                104718                   110.00             2016
# 28                183634                    36.90             2016
# 35                125915                  1075.00             2016
# 151                24912                  1500.00             2016
# ...                  ...                      ...              ...
# 1048443           102427                   200.00             2016
# 1048452            84644                   219.00             2016
# 1048531           184319                   598.86             2016
# 1048533           184049                   520.00             2016
# 1048540           182331                   290.00             2016
#
#          CustomerYear  CustomerAge
# 16             1800.0        216.0
# 22             1800.0        216.0
# 28             1800.0        216.0
# 35             1800.0        216.0
# 151            1800.0        216.0
# ...               ...          ...
# 1048443        1800.0        216.0
# 1048452        1800.0        216.0
# 1048531        1800.0        216.0
# 1048533        1800.0        216.0
# 1048540        1800.0        216.0
#
# [57339 rows x 12 columns]

# %% [markdown]
# Outliers!?

# %%
bank_eda.drop('CustomerDOB',axis=1,inplace=True)

# %%
bank_eda.drop('CustomerYear',axis=1,inplace=True)

# %% [markdown]
# Looks like there are Outliers

# %%
sns.histplot(data=bank_eda,x='CustomerAge',bins=20)
plt.show()

# %%
bank_eda[bank_eda.CustomerAge > 200]
# Out:
#         TransactionID CustomerID CustGender              CustLocation  \
# 16                T17   C1376215          M                    MUMBAI
# 22                T23   C7018081          M  WAYS PANCHKUVA AHMEDABAD
# 28                T29   C7935438          M                    MOHALI
# 35                T36   C1211387          M                 AHMEDABAD
# 151              T152   C3334638          M                      PUNE
# ...               ...        ...        ...                       ...
# 1048443      T1048444   C7261226          M                    BHILAI
# 1048452      T1048453   C3813481          M                 NEW DELHI
# 1048531      T1048532   C6937679          M                 NEW DELHI
# 1048533      T1048534   C7431884          M            MANDIR DHANBAD
# 1048540      T1048541   C1528025          M                    MUMBAI
#
#          CustAccountBalance TransactionDate  TransactionTime  \
# 16                 77495.15      2016-01-08           124727
# 22                   143.07      2016-03-08           104718
# 28                969436.12      2016-03-08           183634
# 35                 11791.25      2016-03-08           125915
# 151                  700.00      2016-09-08            24912
# ...                     ...             ...              ...
# 1048443             1393.33      2016-09-18           102427
# 1048452           984605.24      2016-09-18            84644
# 1048531            50698.90      2016-09-18           184319
# 1048533            53771.64      2016-09-18           184049
# 1048540           230894.59      2016-09-18           182331
#
#          TransactionAmount (INR)  TransactionYear  CustomerAge
# 16                       1423.11             2016        216.0
# 22                        110.00             2016        216.0
# 28                         36.90             2016        216.0
# 35                       1075.00             2016        216.0
# 151                      1500.00             2016        216.0
# ...                          ...              ...          ...
# 1048443                   200.00             2016        216.0
# 1048452                   219.00             2016        216.0
# 1048531                   598.86             2016        216.0
# 1048533                   520.00             2016        216.0
# 1048540                   290.00             2016        216.0
#
# [57339 rows x 10 columns]

# %%
bank_clean = bank_eda[bank_eda.CustomerAge < 100]

# %% [markdown]
# Removed the outliers

# %%
sns.histplot(data=bank_clean,x='CustomerAge',bins=20)
plt.title('Customer Age Histogram')
plt.show()

# %% [markdown]
# Majority customers are in the age group of 20-40

# %%
bank_clean.isna().sum()
# Out:
# TransactionID                 0
# CustomerID                    0
# CustGender                  164
# CustLocation                151
# CustAccountBalance         2194
# TransactionDate               0
# TransactionTime               0
# TransactionAmount (INR)       0
# TransactionYear               0
# CustomerAge                   0
# dtype: int64

# %% [markdown]
# Checking if Account Balance > Transaction Amount

# %%
bank_clean[(bank_clean['CustAccountBalance'] - bank_clean['TransactionAmount (INR)'])<0]
# Out:
#         TransactionID CustomerID CustGender CustLocation  CustAccountBalance  \
# 1                  T2   C2142763          M      JHAJJAR             2270.69
# 26                T27   C5430368          M        DELHI              285.76
# 34                T35   C7017047          M      GURGAON               39.73
# 36                T37   C4320949          F      CHENNAI              213.06
# 46                T47   C8934588          M       JAIPUR             5055.18
# ...               ...        ...        ...          ...                 ...
# 1048537      T1048538   C9016563          M    SHILLLONG             1002.96
# 1048538      T1048539   C3319123          M        DELHI              200.62
# 1048542      T1048543   C6210667          M        MALDA                6.42
# 1048560      T1048561   C5028150          M         PUNE              464.87
# 1048561      T1048562   C1034220          M    BANGALORE             1212.70
#
#         TransactionDate  TransactionTime  TransactionAmount (INR)  \
# 1            2016-02-08           141858                 27999.00
# 26           2016-03-08           160537                  5500.00
# 34           2016-03-08           182715                   110.00
# 36           2016-03-08           182915                  1081.00
# 46           2016-03-08           223146                 13846.00
# ...                 ...              ...                      ...
# 1048537      2016-09-18           183747                  1146.65
# 1048538      2016-09-18           183920                   401.20
# 1048542      2016-09-18           182855                   800.00
# 1048560      2016-09-18           184632                  3000.00
# 1048561      2016-09-18           184734                  1500.00
#
#          TransactionYear  CustomerAge
# 1                   2016         59.0
# 26                  2016         30.0
# 34                  2016         39.0
# 36                  2016         32.0
# 46                  2016         35.0
# ...                  ...          ...
# 1048537             2016         29.0
# 1048538             2016         37.0
# 1048542             2016         27.0
# 1048560             2016         36.0
# 1048561             2016         24.0
#
# [96806 rows x 10 columns]

# %%
bank_clean_2 = bank_clean[(bank_clean['CustAccountBalance'] - bank_clean['TransactionAmount (INR)'])>0]

# %%
bank_clean_2.isna().sum()
# Out:
# TransactionID                0
# CustomerID                   0
# CustGender                 135
# CustLocation               140
# CustAccountBalance           0
# TransactionDate              0
# TransactionTime              0
# TransactionAmount (INR)      0
# TransactionYear              0
# CustomerAge                  0
# dtype: int64

# %%
bank_clean_2['CustGender'].fillna('M',inplace=True)
bank_clean_2['CustLocation'].fillna('MUMBAI',inplace=True)

# %%
bank_clean_2.isna().sum()
# Out:
# TransactionID              0
# CustomerID                 0
# CustGender                 0
# CustLocation               0
# CustAccountBalance         0
# TransactionDate            0
# TransactionTime            0
# TransactionAmount (INR)    0
# TransactionYear            0
# CustomerAge                0
# dtype: int64

# %% [markdown]
# Transactions Amount and Transaction Count by Month

# %%
bank_clean_2['TransactionMonth'] = bank_clean_2['TransactionDate'].dt.month
bank_clean_2.head()
# Out:
#   TransactionID CustomerID CustGender CustLocation  CustAccountBalance  \
# 0            T1   C5841053          F   JAMSHEDPUR            17819.05
# 2            T3   C4417068          F       MUMBAI            17874.44
# 3            T4   C5342380          F       MUMBAI           866503.21
# 4            T5   C9031234          F  NAVI MUMBAI             6714.43
# 5            T6   C1536588          F     ITANAGAR            53609.20
#
#   TransactionDate  TransactionTime  TransactionAmount (INR)  TransactionYear  \
# 0      2016-02-08           143207                     25.0             2016
# 2      2016-02-08           142712                    459.0             2016
# 3      2016-02-08           142714                   2060.0             2016
# 4      2016-02-08           181156                   1762.5             2016
# 5      2016-02-08           173940                    676.0             2016
#
#    CustomerAge  TransactionMonth
# 0         22.0                 2
# 2         20.0                 2
# 3         43.0                 2
# 4         28.0                 2
# 5         44.0                 2

# %%
transactions_num = bank_clean_2[['TransactionAmount (INR)','TransactionMonth']]

# %%
monthly_transactions = transactions_num.groupby('TransactionMonth').agg(['median','count'])
monthly_transactions
# Out:
#                  TransactionAmount (INR)
#                                   median   count
# TransactionMonth
# 1                                384.000   36129
# 2                                400.000   36994
# 3                                477.975   40108
# 4                                500.000   40644
# 5                                415.000   36124
# 6                                454.000   39217
# 7                                480.000   41656
# 8                                400.000  362838
# 9                                378.000  135155
# 10                               433.000   43455
# 11                               465.000   40296
# 12                               396.650   36204

# %% [markdown]
# Median Transaction Amount by Month

# %%
monthly_transactions['TransactionAmount (INR)','median'].plot(kind='line')
plt.title('Median Transaction Amount by Months(1-12)')
plt.xlabel('Month')
plt.ylabel('Median Transaction Amount')
plt.show()

# %% [markdown]
# Number of Transactions by Month

# %%
monthly_transactions['TransactionAmount (INR)','count'].plot(kind='line')
plt.title('Number of Transactions by Months(1-12)')
plt.xlabel('Month')
plt.ylabel('Count of Transactions')
plt.show()

# %% [markdown]
# Principal Component Analysis

# %%
bank = bank_clean_2.copy()
bank.head()
# Out:
#   TransactionID CustomerID CustGender CustLocation  CustAccountBalance  \
# 0            T1   C5841053          F   JAMSHEDPUR            17819.05
# 2            T3   C4417068          F       MUMBAI            17874.44
# 3            T4   C5342380          F       MUMBAI           866503.21
# 4            T5   C9031234          F  NAVI MUMBAI             6714.43
# 5            T6   C1536588          F     ITANAGAR            53609.20
#
#   TransactionDate  TransactionTime  TransactionAmount (INR)  TransactionYear  \
# 0      2016-02-08           143207                     25.0             2016
# 2      2016-02-08           142712                    459.0             2016
# 3      2016-02-08           142714                   2060.0             2016
# 4      2016-02-08           181156                   1762.5             2016
# 5      2016-02-08           173940                    676.0             2016
#
#    CustomerAge  TransactionMonth
# 0         22.0                 2
# 2         20.0                 2
# 3         43.0                 2
# 4         28.0                 2
# 5         44.0                 2

# %%
bank.drop(['TransactionID','CustomerID','CustLocation','TransactionDate','TransactionTime','TransactionYear'],axis=1,inplace=True)

# %%
bank.head()
# Out:
#   CustGender  CustAccountBalance  TransactionAmount (INR)  CustomerAge  \
# 0          F            17819.05                     25.0         22.0
# 2          F            17874.44                    459.0         20.0
# 3          F           866503.21                   2060.0         43.0
# 4          F             6714.43                   1762.5         28.0
# 5          F            53609.20                    676.0         44.0
#
#    TransactionMonth
# 0                 2
# 2                 2
# 3                 2
# 4                 2
# 5                 2

# %%
bank.drop(['TransactionMonth'],axis=1,inplace=True)

# %%
bank.head()
# Out:
#   CustGender  CustAccountBalance  TransactionAmount (INR)  CustomerAge
# 0          F            17819.05                     25.0         22.0
# 2          F            17874.44                    459.0         20.0
# 3          F           866503.21                   2060.0         43.0
# 4          F             6714.43                   1762.5         28.0
# 5          F            53609.20                    676.0         44.0

# %%
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer

num_pipeline = make_pipeline(StandardScaler())
cat_pipeline = make_pipeline(OneHotEncoder())
num_attribs = ['CustAccountBalance','TransactionAmount (INR)','CustomerAge']
cat_attribs = ['CustGender']
preprocessing = ColumnTransformer([
    ('num',num_pipeline,num_attribs),('cat',cat_pipeline,cat_attribs)
])

# %%
bank_df = preprocessing.fit_transform(bank)

# %%
print('Shape of Bank data before PCA:',bank_df.shape)
# Out:
# Shape of Bank data before PCA: (888820, 5)

# %%
from sklearn.decomposition import TruncatedSVD

pca_bank = TruncatedSVD(n_components=4)
pca_bank.fit(bank_df)

bank_transformed = pca_bank.transform(bank_df)
print('Shape of Bank data after PCA:',bank_transformed.shape)
# Out:
# Shape of Bank data after PCA: (888820, 4)

# %% [markdown]
# Plot of Principal Component-2 vs Principal Component-1

# %%
plt.scatter(bank_transformed[:,0],bank_transformed[:,1])
plt.title('PCA on Bank Customer')
plt.xlabel('Principal Component-1')
plt.ylabel('Principal Component-2')
plt.show()

# %% [markdown]
# K Means

# %%
from sklearn.cluster import KMeans

cluster = list(range(1,21))
inertias = []
for clusters in cluster:
    kmeans_bank = KMeans(n_clusters=clusters,n_init='auto',random_state=42)
    kmeans_bank.fit(bank_transformed)
    inertias.append(kmeans_bank.inertia_)

# %% [markdown]
# Knee-Elbow Plot

# %%
plt.plot(cluster,inertias)
plt.xlabel('Number of Clusters')
plt.ylabel('Intertia')
plt.title('Knee-Elbow plot')
plt.grid()
plt.show()

# %% [markdown]
# Principal Components Plot with Labels

# %%
kmeans_chosen = KMeans(n_clusters=5,n_init='auto',random_state=42)
kmeans_chosen.fit(bank_transformed)

plt.scatter(bank_transformed[:,0],bank_transformed[:,1],c=kmeans_chosen.labels_)
plt.title('KMeans with n_clusters=5')
plt.xlabel('Principal Component-1')
plt.ylabel('Principal Component-2')
plt.show()

# %%
bank['Labels'] = kmeans_chosen.labels_

# %%
bank['Labels'].value_counts()
# Out:
# Labels
# 2    700766
# 3    173251
# 0     13352
# 4      1291
# 1       160
# Name: count, dtype: int64

# %%
labels = [0,1,2,3,4]
for label in labels:
    print(f'Cluster no:{label}')
    df_cluster = bank[bank.Labels == label]
    mode_gender = df_cluster['CustGender'].mode()
    mean_accountbalance = df_cluster['CustAccountBalance'].mean()
    mean_transaction_amt = df_cluster['TransactionAmount (INR)'].mean()
    mean_customer_age = df_cluster['CustomerAge'].mean()
    print(f'Most frequent gender:{mode_gender}')
    print(f'Mean Account Balance:{round(mean_accountbalance)}')
    print(f'Mean Transaction Amount (INR):{round(mean_transaction_amt)}')
    print(f'Mean Customer Age:{round(mean_customer_age)}')
# Out:
# Cluster no:0
# Most frequent gender:0    M
# Name: CustGender, dtype: object
# Mean Account Balance:1173587
# Mean Transaction Amount (INR):17674
# Mean Customer Age:37
# Cluster no:1
# Most frequent gender:0    M
# Name: CustGender, dtype: object
# Mean Account Balance:47811714
# Mean Transaction Amount (INR):12343
# Mean Customer Age:59
# Cluster no:2
# Most frequent gender:0    M
# Name: CustGender, dtype: object
# Mean Account Balance:62532
# Mean Transaction Amount (INR):775
# Mean Customer Age:28
# Cluster no:3
# Most frequent gender:0    M
# Name: CustGender, dtype: object
# Mean Account Balance:208864
# Mean Transaction Amount (INR):1418
# Mean Customer Age:45
# Cluster no:4
# Most frequent gender:0    M
# Name: CustGender, dtype: object
# Mean Account Balance:851395
# Mean Transaction Amount (INR):79649
# Mean Customer Age:40

# %% [markdown]
# Cluster 0 : Middle Aged Males who are probably working professionals
# Cluster 1: Senior Males who are well established with a high Account Balance
# Cluster 2: Single Males who are starting out their careers with a relatively low Bank Balance and Transaction Amount
# Cluster 3: Similar characteristics to Cluster 0
# Cluster 4: Simialr characteristics to Cluster 0
